# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
# creating agent
from dotenv import load_dotenv
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver   
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# %%
agent = create_agent(
    model="groq:qwen/qwen3-32b",
      tools=[web_search],
    system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""  ,  checkpointer=InMemorySaver() 
)

# %%
question = HumanMessage(content="i have panner and other vegs like palak  what can i make from it ?")
config = {"configurable": {"thread_id": "1"}}

# %%
response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
print(response['messages'][-1].content.split('</think>')[-1].strip())
# Out:
# Here are some recipe ideas using your paneer and palak (spinach), along with options to incorporate other vegetables:
#
# ### 1. **Classic Palak Paneer**
# A North Indian staple where soft paneer cubes are simmered in a creamy spinach gravy.
# **Ingredients**: Fresh spinach (palak), paneer, garlic, onions, tomatoes, ginger, garam masala, cream (optional).
# **Variation**: Add carrots, broccoli, or peas to the spinach puree for extra veggies.
#
# ### 2. **Restaurant-Style Smoked Palak Paneer**
# A smoky twist with charred spices and herbs for a restaurant-like flavor.
# **Ingredients**: Spinach, paneer, Kashmiri chili, fennel seeds, cumin, cream.
# **Variation**: Toss in grated carrots or bell peppers for texture.
#
# ### 3. **Vegan/vegetarian Twist**
# If you want to use more veggies, try a **Palak Paneer with Mixed Veggies** (carrots, cauliflower, peas) in a light spinach gravy.
#
# Would you like detailed instructions for any of these recipes? Let me know your preference! 🥦🧀

# %%
question = HumanMessage(content="i dont have tomato !!")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

print(response['messages'][-1].content)
# Out:
# No problem! Here are **tomato-free palak paneer recipes** you can make with your paneer and palak:
#
# ---
#
# ### **1. Simple Palak Paneer (Tomato-Free)**
# **Ingredients**:
# - Fresh spinach (palak), blanched and pureed
# - Paneer cubes
# - Onions (finely chopped)
# - Garlic (minced)
# - Ginger (grated)
# - Green chilies (slit)
# - Spices: cumin, garam masala, red chili powder, turmeric
# - Fresh cream (optional, for richness)
#
# **Method**:
# 1. Sauté onions, garlic, and ginger until golden.
# 2. Add blanched spinach puree and spices. Cook until thickened.
# 3. Add paneer cubes and let them simmer in the gravy.
# 4. Finish with a drizzle of cream or a sprinkle of garam masala.
#
# ---
#
# ### **2. Spiced Palak Paneer with Veggies**
# **Ingredients**:
# - Spinach puree
# - Paneer
# - Carrots (grated), broccoli florets, or peas
# - Mustard seeds, cumin seeds, asafoetida
# - Curry leaves (optional)
#
# **Method**:
# 1. Temper mustard/cumin seeds in oil, add curry leaves.
# 2. Mix in spinach puree, grated carrots, and spices. Cook until veggies soften.
# 3. Add paneer and let it absorb the flavors.
#
# ---
#
# ### **3. Smoky Palak Paneer (Charred Flavor)**
# **Ingredients**:
# - Spinach puree
# - Paneer
# - Smoked paprika or charred cumin seeds (for smokiness)
# - Cashew paste (for creaminess without tomatoes)
#
# **Method**:
# 1. Sauté spinach puree with charred cumin and smoked paprika.
# 2. Blend in cashew paste for a creamy texture.
# 3. Add paneer and simmer.
#
# ---
#
# Would you like step-by-step instructions for any of these? 🥦🧀
